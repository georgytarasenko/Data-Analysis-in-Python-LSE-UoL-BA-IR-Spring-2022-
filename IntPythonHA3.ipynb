# %% [markdown]
# # HOME ASSIGNMENT 3
#
# All the code for this assignmnet should be written here in blank chunks. The assignmnet should be submitted via Dropbox in a folder with your group's number ([201](https://www.dropbox.com/request/YClB4vVGmCWmbiIL6HVe), [202](https://www.dropbox.com/request/KOS2Zau8kxxcRIHutEOS), [203](https://www.dropbox.com/request/qJc20mEtxE1PWyBtNNxv), [204](https://www.dropbox.com/request/sL1qneQIOxMIshAM02OF), [205](https://www.dropbox.com/request/vBfpXpuojdzceobu0lO5), [206](https://www.dropbox.com/request/gyp1TU4lSOzLd4lmzO4D)). File name's format 'LastName_FirstName_HA3.ipynb'. We do not accept any files via e-mail or Telegram.
#
# The format of the submission file is .ipynb, all other formats (.py, .pdf, .docx etc) are not accepted; the submission of the wrong format will be graded as zero.
#
# ### DEADLINE: March, 3d, 23:59 MSC
#
# **Late submission policy:** you can submit the assignment after the deadline, but the penalty of **2 points** (out of 10) **per late day** will be applied.

# %% [markdown]
# ### Task 1 (0.25)
#
# Write a program that receives numbers separated by `', '`, makes a list from those numbers, swaps first and last elements and prints all elements of the list each at a new line.
#
# **Input**
#
# Sequence of numbers (separated by `', '`), at least 2 numbers (should be `float`). It is assumed that a user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 6, 9, 1, 0, 2
#
# Output:
# 2
# 9
# 1
# 0
# 6
#
# ### Test 2
# Input:
# 2, 8
#
# Output:
# 8
# 2
# ```

# %%
# your code here

# %% [markdown]
# ### Task 2 (0.25)
#
# Write a program that receives numbers separated by `', '`, makes a list from those numbers, and prints the number of variables suitable to unpack the list using *multiple assignment*. If the task is not clear for you, please consult the beginning of Lecture 5 Notebook.
#
# **Input**
#
# Sequence of numbers (separated by `', '`), at least 1 number (should be `float`). It is assumed that a user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 6, 9, 1, 0, 2
#
# Output:
# 5
#
# ### Test 2
# Input:
# 2, 8
#
# Output:
# 2
# ```

# %%
# your code here

# %% [markdown]
# ### Task 3 (0.25)
#
# Write a program that receives NON-NEGATIVE numbers separated by `', '`, makes a list from those numbers, and prints square root of each number (each on a new line).
#
# **Input**
#
# Sequence of NON-NEGATIVE numbers (separated by `', '`), at least 1 number (should be `float`). It is assumed that a user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 6, 9, 1, 0, 2
#
# Output:
# 2.449489742783178
# 3.0
# 1.0
# 0.0
# 1.4142135623730951
#
# ### Test 2
# Input:
# 2, 8
#
# Output:
# 1.4142135623730951
# 2.8284271247461903
# ```

# %%
# your code here

# %% [markdown]
# ### Task 4 (0.25)
#
# Write a program that makes lists of:
#
# * numbers from `-3` to `9` (including `9`);
# * each second number from `20` to `-1` (excluding `-1`);
# * each 10-th number from `-500` to `80` (including `80`);
# * even numbers from `-40` to `5`.
#
# **Input**
#
# No input.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# Example cannot be provided.
# ```

# %%
# your code here

# %% [markdown]
# ### Task 5 (0.25)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ### Task 6 (0.25)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ### Task 7 (0.25)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ### Task 8 (0.25)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ## IF YOU PROCEED TASKS 1-8, YOU ALREADY HAVE 2/10

# %% [markdown]
# ### Task 9 (0.5)
#
# Write a program that receives positive numbers one by one and prints the result of division of `10` by the current number. If the next in turn number is negative, the program should stop. The program should on each step print `10 divided by <number> equals <result>.`. If current value is `0`, the program should not proceed division but type `Invalid operation: division by zero is prohibited.`.
#
# **Input**
#
# Positive numbers, each at a new line (should be `float`). Negative number signifies the end of the sequence. It is assumed that a user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 6
# 9
# 1
# 0
# 2
# -1
#
# Output:
# 10 divided by 6.0 equals 1.6666666666666667.
# 10 divided by 9.0 equals 1.1111111111111112.
# 10 divided by 1.0 equals 10.0.
# Invalid operation: division by zero is prohibited.
# 10 divided by 2.0 equals 5.0.
#
# ### Test 2
# Input:
# 2
# 8
# -1
#
# Output:
# 10 divided by 2.0 equals 5.0.
# 10 divided by 8.0 equals 1.25.
# ```

# %%
# your code here

# %% [markdown]
# ### Task 10 (0.5)
#
# Write a program that receives a positive integer number (`number`), calculates its [factorial](https://www.britannica.com/science/factorial) (`number!`) and prints the result in the following form: `Factorial of <number> is <result>.`. Assume that factorial of `0` is `1`. `math` library usage is prohibited.
#
# **Input**
#
# A positive integer number (`0` is included). It is assumed that the user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 8
#
# Output:
# Factorial of 8 is 40320.
#
# ### Test 2
# Input:
# 0
#
# Output:
# Factorial of 0 is 1.
# ```

# %%
# your code here

# %% [markdown]
# ### Task 11 (0.5)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ### Task 12 (0.5)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ## IF YOU PROCEED TASKS 1-12, YOU ALREADY HAVE 4/10

# %% [markdown]
# ### Task 13 (1)
#
# For a given natural number `n` where `n <= 9` print the reversed ladder so as to each number (`i` from `n` to 1) repeats `i` times.
#
# **Input**
#
# Natural number `n` where `n <= 9`. It is assumed that a user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 9
#
# Output:
# 999999999
# 88888888
# 7777777
# 666666
# 55555
# 4444
# 333
# 22
# 1
#
# ### Test 2
# Input:
# 4
#
# Output:
# 4444
# 333
# 22
# 1
# ```

# %%
# your code here

# %% [markdown]
# ### Task 14 (1)
#
# The sequence consists of natural values and ends with `-1`. Find the index of its minimum (indexing starts with `0`). If there are a few minima, find the index of the first. Values are taken step by step until they do not equal `-1`.
#
# **Input**
#
# Natural numbers, each at a new line. `-1` signifies the end of the sequence. It is assumed that a user inputs data properly, so the program does not need to check whether the input is correct.
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
# 6
# 9
# 1
# 0
# 2
# -1
#
# Output:
# 3
#
# ### Test 2
# Input:
# 2
# 8
# 2
# -1
#
# Output:
# 0
# ```

# %%
# your code here

# %% [markdown]
# ### Task 15 (1)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ### Task 16 (1)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ## IF YOU PROCEED TASKS 1-16, YOU ALREADY HAVE 8/10

# %% [markdown]
# ### Task 17 (2)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ### Task 18 (2)
#
# **Input**
#
# **Output**
#
# Print the solution of the problem.
#
# **Example**
# ```
# ### Test 1
# Input:
#
# Output:
#
# ### Test 2
# Input:
#
# Output:
#
# ```

# %% [markdown]
# ## IF YOU PROCEED TASKS 1-18, YOU ALREADY HAVE 10/10 AND 2 BONUS SCORES
